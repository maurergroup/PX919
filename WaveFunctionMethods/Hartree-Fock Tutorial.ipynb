# %% [markdown]
# # The Hartree Fock method

# %% [markdown]
# <div class="col-md-10">
# <p> In this tutorial we use a the Python scripting language and an interactive Jupyter notebook to run a Hartree-Fock calculation using the Python-based quantum chemistry code Psi4. </p>
#
#
# <p> You can install this setup on your own Windows/Mac computer following the instructions in the lecture handout.</p>
# </div>
# <div class="col-md-2">
# <img src="http://www.psicode.org/psi4manual/master/_static/psi4square.png" alt="Psi4 code" style="width: 100px;"/>
# </div>
#
# You will see lot's of Python statements that import packages or access functions, such as the following:

# %% [markdown]
# Here we load important packages, such as a visualization programm and the Psi4 software package and then we do a little arithmetics.

# %%
import numpy as np
import matplotlib.pyplot as plt
import psi4
from ase.build import molecule
from ase.atoms import Atoms
from ase.visualize import view
from ase.visualize.plot import plot_atoms

def geom_ase_to_psi4(atoms, charge=0, multiplicity=1, symmetry='c1' ):
    """
    takes an ase atoms object and build a Psi4 geometry string
    """
    species = atoms.get_chemical_symbols()
    pos = atoms.get_positions()
    string = "unit angstrom \n"
    string += "symmetry c1 \n"
    string += "{0} {1} \n".format(charge, multiplicity) 
    for i,(spec,p) in enumerate(zip(species, pos)):
        string += "{0} {1:14.8f} {2:14.8f} {3:14.8f}\n".format(spec, p[0], p[1], p[2])
        
    return string

print(1+1)
# Out:
# 2

# %% [markdown]
# ## Part 1: Theory and Method

# %% [markdown]
# Hartree-Fock Self-Consistent Field Theory (HF-SCF) with restricted orbitals and closed-shell systems (RHF) solves the so-called Rothaan-Hall equation, which is a generalized eigenvalue matrix equation:
#
# \begin{equation}
# \mathbf{FC}=\mathbf{\epsilon S C}
# \end{equation}

# %% [markdown]
# ## Part 2: A simple Hartree-Fock calculation

# %% [markdown]
# ### Step 1: Setting up the molecular coordinates
# ___________
#
# This is the first step of every calculation. We need to define the molecular coordinates.
# The `ase` package contains a lot of handy tools to define molecules with preset geometries.
#
# In the following, we use the functino `molecules` from `ase.build` to build a water molecule.

# %%
#h2o, nh3, BDA, C60, 
atoms = molecule('H2')
print(atoms.positions)
# Out:
# [[ 0.        0.        0.368583]
#  [ 0.        0.       -0.368583]]

# %% [markdown]
# We could have also done this manually, by building an `Atoms` object and setting Cartesian coordinates by hand:

# %%
atoms = Atoms('OH2')
atoms.set_positions([
    [0.,     0.,  0.119262], #H
    [0.,  0.763, -0.477047], #H
    [0., -0.763, -0.477047], #O
])
print(atoms.positions)
# Out:
# [[ 0.        0.        0.119262]
#  [ 0.        0.763    -0.477047]
#  [ 0.       -0.763    -0.477047]]

# %% [markdown]
# Let's visualize the molecule on the screen using `ase.visualize.view`
# There are two possible viewers. 'x3d' is the standard one. 'ngl' or nglview has to be installed separately (see handout) but has a lot more features. Try to replace
#
# `view(atoms, viewer='x3d')` with `view(atoms, viewer='ngl')`

# %%
view(atoms,viewer='x3d') #x3d or ngl
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 0.00 -0.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %% [markdown]
# ### Step 2: Performing the calculation
# ___________
# To calculate the HF energy, we use Psi4. In the following,
#
# * we set the RAM memory, which we allow Psi4 to use,
# * we pass the geometry from our `ase.atoms` object to `psi4.geometry`
# * we initiate the HF (also called scf) calculation using a split-valence 6-31G* Pople basis set
# * we perform the HF energy calculation using `psi4.energy`
# * we extract and print important output data

# %%
psi4.core.clean()
psi4.core.set_output_file('output.dat', False)
psi4.set_memory('1000 MB')

##set geometry
#transform ase geometries to Psi4 input string
geom_input = geom_ase_to_psi4(atoms, charge=0, multiplicity=1)
print(geom_input)
#initiate Psi4 molecule object
nh3 = psi4.geometry(geom_input)

# Set computation options
psi4.set_options({'basis': '3-21G',
                  'reference': 'rhf',
                  'scf_type':'direct',
                  'e_convergence': 1e-8})

E, wvf = psi4.energy('scf',return_wfn=True)
print('Total HF energy is {0} Hartree \n '.format(E))

#Let's look at orbital coefficients, MO energies and occupations
coeffs = wvf.Ca().to_array()
epsilons = wvf.epsilon_a().to_array()
occs = wvf.occupation_a().to_array()

for i,(o,e) in enumerate(zip(occs, epsilons)):
    print ('Molecular Orbital {0}, occupation: {1:4.2f}, energy: {2:8.3f}'.format(i,o,e))

#Write wave functions to molden file format, can be visualized in Avogadro
psi4.molden(wvf, 'C60.molden')
# Out:
# unit angstrom
# symmetry c1
# 0 1
# C     2.21019530     0.58666310     2.66695040
# C     3.10763930     0.15770080     1.63002860
# C     1.32844300    -0.31589390     3.23632320
# C     3.09087090    -1.15850050     1.20142400
# C     3.18792450    -1.45745990    -0.19970050
# C     3.22146230     1.22309660     0.67394400
# C     3.31612100     0.93515860    -0.67651510
# C     3.29849810    -0.43011420    -1.12041380
# C    -0.44808420     1.35914840     3.20810200
# C     0.46720560     2.29498300     2.61752640
# C    -0.02565750     0.07642190     3.50862590
# C     1.77279170     1.91765840     2.35296910
# C     2.39546230     2.30956890     1.11895390
# C    -0.26101950     3.08209350     1.66231170
# C     0.34077260     3.45923880     0.47459680
# C     1.69511710     3.06924460     0.19766230
# C    -2.12583940    -0.84588530     2.67009630
# C    -2.56209900     0.48552020     2.35317150
# C    -0.87815210    -1.04619850     3.23673020
# C    -1.74150960     1.56799630     2.61973330
# C    -1.62624680     2.63570300     1.66418110
# C    -3.29848100     0.43018710     1.12042080
# C    -3.18794690     1.45738950     0.19960300
# C    -2.33602610     2.58136270     0.47609120
# C    -0.50052100    -2.97977710     1.79403080
# C    -1.79443380    -2.77290870     1.20478910
# C    -0.05142450    -2.13288410     2.79388300
# C    -2.58914710    -1.72258280     1.63297150
# C    -3.31607050    -0.93506360     0.67652680
# C    -1.69519190    -3.06925810    -0.19765640
# C    -2.39549010    -2.30968530    -1.11898620
# C    -3.22141820    -1.22318350    -0.67395810
# C     2.17582340    -2.09462630     1.79225290
# C     1.71186190    -2.97496810     0.75571980
# C     1.31306560    -1.68294160     2.79438920
# C     0.39590240    -3.40513950     0.75576380
# C    -0.34082190    -3.45918830    -0.47456100
# C     2.33600570    -2.58144990    -0.47610500
# C     1.62637570    -2.63573490    -1.66423090
# C     0.26113520    -3.08212710    -1.66226180
# C    -2.21008440    -0.58686360    -2.66703000
# C    -1.77269700    -1.91789690    -2.35304660
# C    -0.46707230    -2.29505090    -2.61751050
# C    -1.32835000     0.31576830    -3.23623750
# C    -2.17598820     2.09453830    -1.79232940
# C    -3.09096630     1.15834720    -1.20157490
# C    -3.10760900    -0.15784530    -1.63016270
# C    -1.31313650     1.68282920    -2.79436390
# C     0.50032240     2.97996370    -1.79402030
# C    -0.39611480     3.40528170    -0.75572720
# C    -1.71206290     2.97491220    -0.75579880
# C     0.05128240     2.13294780    -2.79374500
# C     2.12586300     0.84608090    -2.67005340
# C     2.58918530     1.72277420    -1.63295620
# C     1.79430100     2.77306840    -1.20482620
# C     0.87813230     1.04635140    -3.23653130
# C     0.44824520    -1.35910610    -3.20805100
# C     1.74169480    -1.56795570    -2.61977140
# C     2.56217240    -0.48535290    -2.35320260
# C     0.02579040    -0.07635670    -3.50844460
#
# Total HF energy is -2259.031234981615 Hartree
#
# Molecular Orbital 0, occupation: 1.00, energy:  -11.245
# Molecular Orbital 1, occupation: 1.00, energy:  -11.245
# Molecular Orbital 2, occupation: 1.00, energy:  -11.245
# Molecular Orbital 3, occupation: 1.00, energy:  -11.245
# Molecular Orbital 4, occupation: 1.00, energy:  -11.245
# Molecular Orbital 5, occupation: 1.00, energy:  -11.245
# Molecular Orbital 6, occupation: 1.00, energy:  -11.245
# Molecular Orbital 7, occupation: 1.00, energy:  -11.245
# Molecular Orbital 8, occupation: 1.00, energy:  -11.245
# Molecular Orbital 9, occupation: 1.00, energy:  -11.245
# Molecular Orbital 10, occupation: 1.00, energy:  -11.245
# Molecular Orbital 11, occupation: 1.00, energy:  -11.245
# Molecular Orbital 12, occupation: 1.00, energy:  -11.244
# Molecular Orbital 13, occupation: 1.00, energy:  -11.244
# Molecular Orbital 14, occupation: 1.00, energy:  -11.244
# Molecular Orbital 15, occupation: 1.00, energy:  -11.244
# Molecular Orbital 16, occupation: 1.00, energy:  -11.244
# Molecular Orbital 17, occupation: 1.00, energy:  -11.244
# Molecular Orbital 18, occupation: 1.00, energy:  -11.244
# Molecular Orbital 19, occupation: 1.00, energy:  -11.244
# Molecular Orbital 20, occupation: 1.00, energy:  -11.244
# Molecular Orbital 21, occupation: 1.00, energy:  -11.244
# Molecular Orbital 22, occupation: 1.00, energy:  -11.244
# Molecular Orbital 23, occupation: 1.00, energy:  -11.244
# Molecular Orbital 24, occupation: 1.00, energy:  -11.244
# Molecular Orbital 25, occupation: 1.00, energy:  -11.244
# Molecular Orbital 26, occupation: 1.00, energy:  -11.244
# Molecular Orbital 27, occupation: 1.00, energy:  -11.244
# Molecular Orbital 28, occupation: 1.00, energy:  -11.244
# Molecular Orbital 29, occupation: 1.00, energy:  -11.244
# Molecular Orbital 30, occupation: 1.00, energy:  -11.244
# Molecular Orbital 31, occupation: 1.00, energy:  -11.244
# Molecular Orbital 32, occupation: 1.00, energy:  -11.244
# Molecular Orbital 33, occupation: 1.00, energy:  -11.244
# Molecular Orbital 34, occupation: 1.00, energy:  -11.244
# Molecular Orbital 35, occupation: 1.00, energy:  -11.244
# Molecular Orbital 36, occupation: 1.00, energy:  -11.244
# Molecular Orbital 37, occupation: 1.00, energy:  -11.244
# Molecular Orbital 38, occupation: 1.00, energy:  -11.244
# Molecular Orbital 39, occupation: 1.00, energy:  -11.244
# Molecular Orbital 40, occupation: 1.00, energy:  -11.244
# Molecular Orbital 41, occupation: 1.00, energy:  -11.244
# Molecular Orbital 42, occupation: 1.00, energy:  -11.244
# Molecular Orbital 43, occupation: 1.00, energy:  -11.244
# Molecular Orbital 44, occupation: 1.00, energy:  -11.243
# Molecular Orbital 45, occupation: 1.00, energy:  -11.243
# Molecular Orbital 46, occupation: 1.00, energy:  -11.243
# Molecular Orbital 47, occupation: 1.00, energy:  -11.243
# Molecular Orbital 48, occupation: 1.00, energy:  -11.243
# Molecular Orbital 49, occupation: 1.00, energy:  -11.243
# Molecular Orbital 50, occupation: 1.00, energy:  -11.243
# Molecular Orbital 51, occupation: 1.00, energy:  -11.243
# Molecular Orbital 52, occupation: 1.00, energy:  -11.243
# Molecular Orbital 53, occupation: 1.00, energy:  -11.243
# Molecular Orbital 54, occupation: 1.00, energy:  -11.243
# Molecular Orbital 55, occupation: 1.00, energy:  -11.243
# Molecular Orbital 56, occupation: 1.00, energy:  -11.243
# Molecular Orbital 57, occupation: 1.00, energy:  -11.243
# Molecular Orbital 58, occupation: 1.00, energy:  -11.243
# Molecular Orbital 59, occupation: 1.00, energy:  -11.242
# Molecular Orbital 60, occupation: 1.00, energy:   -1.327
# Molecular Orbital 61, occupation: 1.00, energy:   -1.302
# Molecular Orbital 62, occupation: 1.00, energy:   -1.302
# Molecular Orbital 63, occupation: 1.00, energy:   -1.302
# Molecular Orbital 64, occupation: 1.00, energy:   -1.254
# Molecular Orbital 65, occupation: 1.00, energy:   -1.254
# Molecular Orbital 66, occupation: 1.00, energy:   -1.254
# Molecular Orbital 67, occupation: 1.00, energy:   -1.253
# Molecular Orbital 68, occupation: 1.00, energy:   -1.253
# Molecular Orbital 69, occupation: 1.00, energy:   -1.203
# Molecular Orbital 70, occupation: 1.00, energy:   -1.202
# Molecular Orbital 71, occupation: 1.00, energy:   -1.202
# Molecular Orbital 72, occupation: 1.00, energy:   -1.161
# Molecular Orbital 73, occupation: 1.00, energy:   -1.161
# Molecular Orbital 74, occupation: 1.00, energy:   -1.161
# Molecular Orbital 75, occupation: 1.00, energy:   -1.161
# Molecular Orbital 76, occupation: 1.00, energy:   -1.096
# Molecular Orbital 77, occupation: 1.00, energy:   -1.096
# Molecular Orbital 78, occupation: 1.00, energy:   -1.095
# Molecular Orbital 79, occupation: 1.00, energy:   -1.095
# Molecular Orbital 80, occupation: 1.00, energy:   -1.095
# Molecular Orbital 81, occupation: 1.00, energy:   -1.074
# Molecular Orbital 82, occupation: 1.00, energy:   -1.074
# Molecular Orbital 83, occupation: 1.00, energy:   -1.074
# Molecular Orbital 84, occupation: 1.00, energy:   -1.074
# Molecular Orbital 85, occupation: 1.00, energy:   -1.001
# Molecular Orbital 86, occupation: 1.00, energy:   -1.001
# Molecular Orbital 87, occupation: 1.00, energy:   -1.001
# Molecular Orbital 88, occupation: 1.00, energy:   -1.001
# Molecular Orbital 89, occupation: 1.00, energy:   -1.001
# Molecular Orbital 90, occupation: 1.00, energy:   -0.981
# Molecular Orbital 91, occupation: 1.00, energy:   -0.981
# Molecular Orbital 92, occupation: 1.00, energy:   -0.981
# Molecular Orbital 93, occupation: 1.00, energy:   -0.923
# Molecular Orbital 94, occupation: 1.00, energy:   -0.923
# Molecular Orbital 95, occupation: 1.00, energy:   -0.923
# Molecular Orbital 96, occupation: 1.00, energy:   -0.877
# Molecular Orbital 97, occupation: 1.00, energy:   -0.876
# Molecular Orbital 98, occupation: 1.00, energy:   -0.876
# Molecular Orbital 99, occupation: 1.00, energy:   -0.876
# Molecular Orbital 100, occupation: 1.00, energy:   -0.876
# Molecular Orbital 101, occupation: 1.00, energy:   -0.876
# Molecular Orbital 102, occupation: 1.00, energy:   -0.876
# Molecular Orbital 103, occupation: 1.00, energy:   -0.876
# Molecular Orbital 104, occupation: 1.00, energy:   -0.837
# Molecular Orbital 105, occupation: 1.00, energy:   -0.784
# Molecular Orbital 106, occupation: 1.00, energy:   -0.784
# Molecular Orbital 107, occupation: 1.00, energy:   -0.784
# Molecular Orbital 108, occupation: 1.00, energy:   -0.784
# Molecular Orbital 109, occupation: 1.00, energy:   -0.756
# Molecular Orbital 110, occupation: 1.00, energy:   -0.756
# Molecular Orbital 111, occupation: 1.00, energy:   -0.756
# Molecular Orbital 112, occupation: 1.00, energy:   -0.756
# Molecular Orbital 113, occupation: 1.00, energy:   -0.756
# Molecular Orbital 114, occupation: 1.00, energy:   -0.734
# Molecular Orbital 115, occupation: 1.00, energy:   -0.734
# Molecular Orbital 116, occupation: 1.00, energy:   -0.734
# Molecular Orbital 117, occupation: 1.00, energy:   -0.695
# Molecular Orbital 118, occupation: 1.00, energy:   -0.695
# Molecular Orbital 119, occupation: 1.00, energy:   -0.695
# Molecular Orbital 120, occupation: 1.00, energy:   -0.674
# Molecular Orbital 121, occupation: 1.00, energy:   -0.665
# Molecular Orbital 122, occupation: 1.00, energy:   -0.665
# Molecular Orbital 123, occupation: 1.00, energy:   -0.665
# Molecular Orbital 124, occupation: 1.00, energy:   -0.665
# Molecular Orbital 125, occupation: 1.00, energy:   -0.644
# Molecular Orbital 126, occupation: 1.00, energy:   -0.644
# Molecular Orbital 127, occupation: 1.00, energy:   -0.644
# Molecular Orbital 128, occupation: 1.00, energy:   -0.644
# Molecular Orbital 129, occupation: 1.00, energy:   -0.644
# Molecular Orbital 130, occupation: 1.00, energy:   -0.643
# Molecular Orbital 131, occupation: 1.00, energy:   -0.643
# Molecular Orbital 132, occupation: 1.00, energy:   -0.643
# Molecular Orbital 133, occupation: 1.00, energy:   -0.624
# Molecular Orbital 134, occupation: 1.00, energy:   -0.624
# Molecular Orbital 135, occupation: 1.00, energy:   -0.624
# Molecular Orbital 136, occupation: 1.00, energy:   -0.623
# Molecular Orbital 137, occupation: 1.00, energy:   -0.610
# Molecular Orbital 138, occupation: 1.00, energy:   -0.610
# Molecular Orbital 139, occupation: 1.00, energy:   -0.609
# Molecular Orbital 140, occupation: 1.00, energy:   -0.589
# Molecular Orbital 141, occupation: 1.00, energy:   -0.589
# Molecular Orbital 142, occupation: 1.00, energy:   -0.589
# Molecular Orbital 143, occupation: 1.00, energy:   -0.589
# Molecular Orbital 144, occupation: 1.00, energy:   -0.580
# Molecular Orbital 145, occupation: 1.00, energy:   -0.580
# Molecular Orbital 146, occupation: 1.00, energy:   -0.580
# Molecular Orbital 147, occupation: 1.00, energy:   -0.580
# Molecular Orbital 148, occupation: 1.00, energy:   -0.580
# Molecular Orbital 149, occupation: 1.00, energy:   -0.528
# Molecular Orbital 150, occupation: 1.00, energy:   -0.528
# Molecular Orbital 151, occupation: 1.00, energy:   -0.527
# Molecular Orbital 152, occupation: 1.00, energy:   -0.527
# Molecular Orbital 153, occupation: 1.00, energy:   -0.527
# Molecular Orbital 154, occupation: 1.00, energy:   -0.514
# Molecular Orbital 155, occupation: 1.00, energy:   -0.513
# Molecular Orbital 156, occupation: 1.00, energy:   -0.513
# Molecular Orbital 157, occupation: 1.00, energy:   -0.513
# Molecular Orbital 158, occupation: 1.00, energy:   -0.513
# Molecular Orbital 159, occupation: 1.00, energy:   -0.498
# Molecular Orbital 160, occupation: 1.00, energy:   -0.498
# Molecular Orbital 161, occupation: 1.00, energy:   -0.498
# Molecular Orbital 162, occupation: 1.00, energy:   -0.478
# Molecular Orbital 163, occupation: 1.00, energy:   -0.478
# Molecular Orbital 164, occupation: 1.00, energy:   -0.478
# Molecular Orbital 165, occupation: 1.00, energy:   -0.478
# Molecular Orbital 166, occupation: 1.00, energy:   -0.377
# Molecular Orbital 167, occupation: 1.00, energy:   -0.377
# Molecular Orbital 168, occupation: 1.00, energy:   -0.377
# Molecular Orbital 169, occupation: 1.00, energy:   -0.377
# Molecular Orbital 170, occupation: 1.00, energy:   -0.368
# Molecular Orbital 171, occupation: 1.00, energy:   -0.368
# Molecular Orbital 172, occupation: 1.00, energy:   -0.368
# Molecular Orbital 173, occupation: 1.00, energy:   -0.368
# Molecular Orbital 174, occupation: 1.00, energy:   -0.368
# Molecular Orbital 175, occupation: 1.00, energy:   -0.301
# Molecular Orbital 176, occupation: 1.00, energy:   -0.301
# Molecular Orbital 177, occupation: 1.00, energy:   -0.301
# Molecular Orbital 178, occupation: 1.00, energy:   -0.301
# Molecular Orbital 179, occupation: 1.00, energy:   -0.301
# Molecular Orbital 180, occupation: 0.00, energy:   -0.032
# Molecular Orbital 181, occupation: 0.00, energy:   -0.032
# Molecular Orbital 182, occupation: 0.00, energy:   -0.032
# Molecular Orbital 183, occupation: 0.00, energy:    0.030
# Molecular Orbital 184, occupation: 0.00, energy:    0.031
# Molecular Orbital 185, occupation: 0.00, energy:    0.031
# Molecular Orbital 186, occupation: 0.00, energy:    0.098
# Molecular Orbital 187, occupation: 0.00, energy:    0.098
# Molecular Orbital 188, occupation: 0.00, energy:    0.099
# Molecular Orbital 189, occupation: 0.00, energy:    0.099
# Molecular Orbital 190, occupation: 0.00, energy:    0.099
# Molecular Orbital 191, occupation: 0.00, energy:    0.100
# Molecular Orbital 192, occupation: 0.00, energy:    0.100
# Molecular Orbital 193, occupation: 0.00, energy:    0.100
# Molecular Orbital 194, occupation: 0.00, energy:    0.189
# Molecular Orbital 195, occupation: 0.00, energy:    0.189
# Molecular Orbital 196, occupation: 0.00, energy:    0.189
# Molecular Orbital 197, occupation: 0.00, energy:    0.189
# Molecular Orbital 198, occupation: 0.00, energy:    0.190
# Molecular Orbital 199, occupation: 0.00, energy:    0.222
# Molecular Orbital 200, occupation: 0.00, energy:    0.222
# Molecular Orbital 201, occupation: 0.00, energy:    0.223
# Molecular Orbital 202, occupation: 0.00, energy:    0.223
# Molecular Orbital 203, occupation: 0.00, energy:    0.256
# Molecular Orbital 204, occupation: 0.00, energy:    0.256
# Molecular Orbital 205, occupation: 0.00, energy:    0.257
# Molecular Orbital 206, occupation: 0.00, energy:    0.257
# Molecular Orbital 207, occupation: 0.00, energy:    0.290
# Molecular Orbital 208, occupation: 0.00, energy:    0.290
# Molecular Orbital 209, occupation: 0.00, energy:    0.290
# Molecular Orbital 210, occupation: 0.00, energy:    0.292
# Molecular Orbital 211, occupation: 0.00, energy:    0.292
# Molecular Orbital 212, occupation: 0.00, energy:    0.293
# Molecular Orbital 213, occupation: 0.00, energy:    0.323
# Molecular Orbital 214, occupation: 0.00, energy:    0.323
# Molecular Orbital 215, occupation: 0.00, energy:    0.323
# Molecular Orbital 216, occupation: 0.00, energy:    0.323
# Molecular Orbital 217, occupation: 0.00, energy:    0.324
# Molecular Orbital 218, occupation: 0.00, energy:    0.361
# Molecular Orbital 219, occupation: 0.00, energy:    0.361
# Molecular Orbital 220, occupation: 0.00, energy:    0.361
# Molecular Orbital 221, occupation: 0.00, energy:    0.365
# Molecular Orbital 222, occupation: 0.00, energy:    0.365
# Molecular Orbital 223, occupation: 0.00, energy:    0.365
# Molecular Orbital 224, occupation: 0.00, energy:    0.387
# Molecular Orbital 225, occupation: 0.00, energy:    0.387
# Molecular Orbital 226, occupation: 0.00, energy:    0.387
# Molecular Orbital 227, occupation: 0.00, energy:    0.387
# Molecular Orbital 228, occupation: 0.00, energy:    0.416
# Molecular Orbital 229, occupation: 0.00, energy:    0.417
# Molecular Orbital 230, occupation: 0.00, energy:    0.417
# Molecular Orbital 231, occupation: 0.00, energy:    0.417
# Molecular Orbital 232, occupation: 0.00, energy:    0.417
# Molecular Orbital 233, occupation: 0.00, energy:    0.455
# Molecular Orbital 234, occupation: 0.00, energy:    0.455
# Molecular Orbital 235, occupation: 0.00, energy:    0.455
# Molecular Orbital 236, occupation: 0.00, energy:    0.455
# Molecular Orbital 237, occupation: 0.00, energy:    0.493
# Molecular Orbital 238, occupation: 0.00, energy:    0.493
# Molecular Orbital 239, occupation: 0.00, energy:    0.493
# Molecular Orbital 240, occupation: 0.00, energy:    0.493
# Molecular Orbital 241, occupation: 0.00, energy:    0.493
# Molecular Orbital 242, occupation: 0.00, energy:    0.527
# Molecular Orbital 243, occupation: 0.00, energy:    0.527
# Molecular Orbital 244, occupation: 0.00, energy:    0.528
# Molecular Orbital 245, occupation: 0.00, energy:    0.547
# Molecular Orbital 246, occupation: 0.00, energy:    0.547
# Molecular Orbital 247, occupation: 0.00, energy:    0.547
# Molecular Orbital 248, occupation: 0.00, energy:    0.588
# Molecular Orbital 249, occupation: 0.00, energy:    0.589
# Molecular Orbital 250, occupation: 0.00, energy:    0.589
# Molecular Orbital 251, occupation: 0.00, energy:    0.609
# Molecular Orbital 252, occupation: 0.00, energy:    0.609
# Molecular Orbital 253, occupation: 0.00, energy:    0.610
# Molecular Orbital 254, occupation: 0.00, energy:    0.610
# Molecular Orbital 255, occupation: 0.00, energy:    0.610
# Molecular Orbital 256, occupation: 0.00, energy:    0.683
# Molecular Orbital 257, occupation: 0.00, energy:    0.683
# Molecular Orbital 258, occupation: 0.00, energy:    0.683
# Molecular Orbital 259, occupation: 0.00, energy:    0.719
# Molecular Orbital 260, occupation: 0.00, energy:    0.720
# Molecular Orbital 261, occupation: 0.00, energy:    0.720
# Molecular Orbital 262, occupation: 0.00, energy:    0.720
# Molecular Orbital 263, occupation: 0.00, energy:    0.727
# Molecular Orbital 264, occupation: 0.00, energy:    0.727
# Molecular Orbital 265, occupation: 0.00, energy:    0.727
# Molecular Orbital 266, occupation: 0.00, energy:    0.728
# Molecular Orbital 267, occupation: 0.00, energy:    0.728
# Molecular Orbital 268, occupation: 0.00, energy:    0.730
# Molecular Orbital 269, occupation: 0.00, energy:    0.730
# Molecular Orbital 270, occupation: 0.00, energy:    0.730
# Molecular Orbital 271, occupation: 0.00, energy:    0.731
# Molecular Orbital 272, occupation: 0.00, energy:    0.768
# Molecular Orbital 273, occupation: 0.00, energy:    0.768
# Molecular Orbital 274, occupation: 0.00, energy:    0.769
# Molecular Orbital 275, occupation: 0.00, energy:    0.792
# Molecular Orbital 276, occupation: 0.00, energy:    0.792
# Molecular Orbital 277, occupation: 0.00, energy:    0.793
# Molecular Orbital 278, occupation: 0.00, energy:    0.793
# Molecular Orbital 279, occupation: 0.00, energy:    0.822
# Molecular Orbital 280, occupation: 0.00, energy:    0.823
# Molecular Orbital 281, occupation: 0.00, energy:    0.823
# Molecular Orbital 282, occupation: 0.00, energy:    0.823
# Molecular Orbital 283, occupation: 0.00, energy:    0.823
# Molecular Orbital 284, occupation: 0.00, energy:    0.839
# Molecular Orbital 285, occupation: 0.00, energy:    0.853
# Molecular Orbital 286, occupation: 0.00, energy:    0.854
# Molecular Orbital 287, occupation: 0.00, energy:    0.854
# Molecular Orbital 288, occupation: 0.00, energy:    0.854
# Molecular Orbital 289, occupation: 0.00, energy:    0.854
# Molecular Orbital 290, occupation: 0.00, energy:    0.873
# Molecular Orbital 291, occupation: 0.00, energy:    0.884
# Molecular Orbital 292, occupation: 0.00, energy:    0.884
# Molecular Orbital 293, occupation: 0.00, energy:    0.884
# Molecular Orbital 294, occupation: 0.00, energy:    0.924
# Molecular Orbital 295, occupation: 0.00, energy:    0.924
# Molecular Orbital 296, occupation: 0.00, energy:    0.924
# Molecular Orbital 297, occupation: 0.00, energy:    0.924
# Molecular Orbital 298, occupation: 0.00, energy:    0.924
# Molecular Orbital 299, occupation: 0.00, energy:    0.933
# Molecular Orbital 300, occupation: 0.00, energy:    0.933
# Molecular Orbital 301, occupation: 0.00, energy:    0.933
# Molecular Orbital 302, occupation: 0.00, energy:    0.942
# Molecular Orbital 303, occupation: 0.00, energy:    0.942
# Molecular Orbital 304, occupation: 0.00, energy:    0.942
# Molecular Orbital 305, occupation: 0.00, energy:    0.943
# Molecular Orbital 306, occupation: 0.00, energy:    0.954
# Molecular Orbital 307, occupation: 0.00, energy:    0.954
# Molecular Orbital 308, occupation: 0.00, energy:    0.954
# Molecular Orbital 309, occupation: 0.00, energy:    0.956
# Molecular Orbital 310, occupation: 0.00, energy:    0.956
# Molecular Orbital 311, occupation: 0.00, energy:    0.957
# Molecular Orbital 312, occupation: 0.00, energy:    0.966
# Molecular Orbital 313, occupation: 0.00, energy:    0.967
# Molecular Orbital 314, occupation: 0.00, energy:    0.967
# Molecular Orbital 315, occupation: 0.00, energy:    0.967
# Molecular Orbital 316, occupation: 0.00, energy:    0.975
# Molecular Orbital 317, occupation: 0.00, energy:    0.975
# Molecular Orbital 318, occupation: 0.00, energy:    0.975
# Molecular Orbital 319, occupation: 0.00, energy:    0.975
# Molecular Orbital 320, occupation: 0.00, energy:    0.975
# Molecular Orbital 321, occupation: 0.00, energy:    0.976
# Molecular Orbital 322, occupation: 0.00, energy:    0.976
# Molecular Orbital 323, occupation: 0.00, energy:    0.976
# Molecular Orbital 324, occupation: 0.00, energy:    0.976
# Molecular Orbital 325, occupation: 0.00, energy:    0.999
# Molecular Orbital 326, occupation: 0.00, energy:    0.999
# Molecular Orbital 327, occupation: 0.00, energy:    0.999
# Molecular Orbital 328, occupation: 0.00, energy:    1.015
# Molecular Orbital 329, occupation: 0.00, energy:    1.015
# Molecular Orbital 330, occupation: 0.00, energy:    1.015
# Molecular Orbital 331, occupation: 0.00, energy:    1.018
# Molecular Orbital 332, occupation: 0.00, energy:    1.048
# Molecular Orbital 333, occupation: 0.00, energy:    1.048
# Molecular Orbital 334, occupation: 0.00, energy:    1.048
# Molecular Orbital 335, occupation: 0.00, energy:    1.048
# Molecular Orbital 336, occupation: 0.00, energy:    1.052
# Molecular Orbital 337, occupation: 0.00, energy:    1.052
# Molecular Orbital 338, occupation: 0.00, energy:    1.052
# Molecular Orbital 339, occupation: 0.00, energy:    1.052
# Molecular Orbital 340, occupation: 0.00, energy:    1.052
# Molecular Orbital 341, occupation: 0.00, energy:    1.061
# Molecular Orbital 342, occupation: 0.00, energy:    1.061
# Molecular Orbital 343, occupation: 0.00, energy:    1.061
# Molecular Orbital 344, occupation: 0.00, energy:    1.061
# Molecular Orbital 345, occupation: 0.00, energy:    1.062
# Molecular Orbital 346, occupation: 0.00, energy:    1.062
# Molecular Orbital 347, occupation: 0.00, energy:    1.062
# Molecular Orbital 348, occupation: 0.00, energy:    1.062
# Molecular Orbital 349, occupation: 0.00, energy:    1.063
# Molecular Orbital 350, occupation: 0.00, energy:    1.063
# Molecular Orbital 351, occupation: 0.00, energy:    1.063
# Molecular Orbital 352, occupation: 0.00, energy:    1.063
# Molecular Orbital 353, occupation: 0.00, energy:    1.063
# Molecular Orbital 354, occupation: 0.00, energy:    1.065
# Molecular Orbital 355, occupation: 0.00, energy:    1.065
# Molecular Orbital 356, occupation: 0.00, energy:    1.065
# Molecular Orbital 357, occupation: 0.00, energy:    1.065
# Molecular Orbital 358, occupation: 0.00, energy:    1.079
# Molecular Orbital 359, occupation: 0.00, energy:    1.079
# Molecular Orbital 360, occupation: 0.00, energy:    1.079
# Molecular Orbital 361, occupation: 0.00, energy:    1.082
# Molecular Orbital 362, occupation: 0.00, energy:    1.083
# Molecular Orbital 363, occupation: 0.00, energy:    1.083
# Molecular Orbital 364, occupation: 0.00, energy:    1.084
# Molecular Orbital 365, occupation: 0.00, energy:    1.084
# Molecular Orbital 366, occupation: 0.00, energy:    1.084
# Molecular Orbital 367, occupation: 0.00, energy:    1.089
# Molecular Orbital 368, occupation: 0.00, energy:    1.089
# Molecular Orbital 369, occupation: 0.00, energy:    1.089
# Molecular Orbital 370, occupation: 0.00, energy:    1.089
# Molecular Orbital 371, occupation: 0.00, energy:    1.089
# Molecular Orbital 372, occupation: 0.00, energy:    1.091
# Molecular Orbital 373, occupation: 0.00, energy:    1.091
# Molecular Orbital 374, occupation: 0.00, energy:    1.091
# Molecular Orbital 375, occupation: 0.00, energy:    1.092
# Molecular Orbital 376, occupation: 0.00, energy:    1.094
# Molecular Orbital 377, occupation: 0.00, energy:    1.095
# Molecular Orbital 378, occupation: 0.00, energy:    1.095
# Molecular Orbital 379, occupation: 0.00, energy:    1.095
# Molecular Orbital 380, occupation: 0.00, energy:    1.184
# Molecular Orbital 381, occupation: 0.00, energy:    1.184
# Molecular Orbital 382, occupation: 0.00, energy:    1.184
# Molecular Orbital 383, occupation: 0.00, energy:    1.201
# Molecular Orbital 384, occupation: 0.00, energy:    1.202
# Molecular Orbital 385, occupation: 0.00, energy:    1.202
# Molecular Orbital 386, occupation: 0.00, energy:    1.202
# Molecular Orbital 387, occupation: 0.00, energy:    1.202
# Molecular Orbital 388, occupation: 0.00, energy:    1.219
# Molecular Orbital 389, occupation: 0.00, energy:    1.231
# Molecular Orbital 390, occupation: 0.00, energy:    1.231
# Molecular Orbital 391, occupation: 0.00, energy:    1.231
# Molecular Orbital 392, occupation: 0.00, energy:    1.295
# Molecular Orbital 393, occupation: 0.00, energy:    1.296
# Molecular Orbital 394, occupation: 0.00, energy:    1.296
# Molecular Orbital 395, occupation: 0.00, energy:    1.297
# Molecular Orbital 396, occupation: 0.00, energy:    1.338
# Molecular Orbital 397, occupation: 0.00, energy:    1.339
# Molecular Orbital 398, occupation: 0.00, energy:    1.339
# Molecular Orbital 399, occupation: 0.00, energy:    1.339
# Molecular Orbital 400, occupation: 0.00, energy:    1.339
# Molecular Orbital 401, occupation: 0.00, energy:    1.342
# Molecular Orbital 402, occupation: 0.00, energy:    1.343
# Molecular Orbital 403, occupation: 0.00, energy:    1.343
# Molecular Orbital 404, occupation: 0.00, energy:    1.343
# Molecular Orbital 405, occupation: 0.00, energy:    1.344
# Molecular Orbital 406, occupation: 0.00, energy:    1.355
# Molecular Orbital 407, occupation: 0.00, energy:    1.355
# Molecular Orbital 408, occupation: 0.00, energy:    1.355
# Molecular Orbital 409, occupation: 0.00, energy:    1.355
# Molecular Orbital 410, occupation: 0.00, energy:    1.355
# Molecular Orbital 411, occupation: 0.00, energy:    1.366
# Molecular Orbital 412, occupation: 0.00, energy:    1.366
# Molecular Orbital 413, occupation: 0.00, energy:    1.367
# Molecular Orbital 414, occupation: 0.00, energy:    1.367
# Molecular Orbital 415, occupation: 0.00, energy:    1.419
# Molecular Orbital 416, occupation: 0.00, energy:    1.419
# Molecular Orbital 417, occupation: 0.00, energy:    1.421
# Molecular Orbital 418, occupation: 0.00, energy:    1.459
# Molecular Orbital 419, occupation: 0.00, energy:    1.460
# Molecular Orbital 420, occupation: 0.00, energy:    1.461
# Molecular Orbital 421, occupation: 0.00, energy:    1.479
# Molecular Orbital 422, occupation: 0.00, energy:    1.479
# Molecular Orbital 423, occupation: 0.00, energy:    1.479
# Molecular Orbital 424, occupation: 0.00, energy:    1.504
# Molecular Orbital 425, occupation: 0.00, energy:    1.504
# Molecular Orbital 426, occupation: 0.00, energy:    1.504
# Molecular Orbital 427, occupation: 0.00, energy:    1.506
# Molecular Orbital 428, occupation: 0.00, energy:    1.506
# Molecular Orbital 429, occupation: 0.00, energy:    1.506
# Molecular Orbital 430, occupation: 0.00, energy:    1.506
# Molecular Orbital 431, occupation: 0.00, energy:    1.507
# Molecular Orbital 432, occupation: 0.00, energy:    1.529
# Molecular Orbital 433, occupation: 0.00, energy:    1.529
# Molecular Orbital 434, occupation: 0.00, energy:    1.529
# Molecular Orbital 435, occupation: 0.00, energy:    1.529
# Molecular Orbital 436, occupation: 0.00, energy:    1.530
# Molecular Orbital 437, occupation: 0.00, energy:    1.554
# Molecular Orbital 438, occupation: 0.00, energy:    1.554
# Molecular Orbital 439, occupation: 0.00, energy:    1.555
# Molecular Orbital 440, occupation: 0.00, energy:    1.555
# Molecular Orbital 441, occupation: 0.00, energy:    1.567
# Molecular Orbital 442, occupation: 0.00, energy:    1.567
# Molecular Orbital 443, occupation: 0.00, energy:    1.567
# Molecular Orbital 444, occupation: 0.00, energy:    1.567
# Molecular Orbital 445, occupation: 0.00, energy:    1.572
# Molecular Orbital 446, occupation: 0.00, energy:    1.572
# Molecular Orbital 447, occupation: 0.00, energy:    1.572
# Molecular Orbital 448, occupation: 0.00, energy:    1.572
# Molecular Orbital 449, occupation: 0.00, energy:    1.573
# Molecular Orbital 450, occupation: 0.00, energy:    1.577
# Molecular Orbital 451, occupation: 0.00, energy:    1.577
# Molecular Orbital 452, occupation: 0.00, energy:    1.577
# Molecular Orbital 453, occupation: 0.00, energy:    1.596
# Molecular Orbital 454, occupation: 0.00, energy:    1.596
# Molecular Orbital 455, occupation: 0.00, energy:    1.596
# Molecular Orbital 456, occupation: 0.00, energy:    1.629
# Molecular Orbital 457, occupation: 0.00, energy:    1.629
# Molecular Orbital 458, occupation: 0.00, energy:    1.629
# Molecular Orbital 459, occupation: 0.00, energy:    1.637
# Molecular Orbital 460, occupation: 0.00, energy:    1.637
# Molecular Orbital 461, occupation: 0.00, energy:    1.638
# Molecular Orbital 462, occupation: 0.00, energy:    1.638
# Molecular Orbital 463, occupation: 0.00, energy:    1.639
# Molecular Orbital 464, occupation: 0.00, energy:    1.660
# Molecular Orbital 465, occupation: 0.00, energy:    1.661
# Molecular Orbital 466, occupation: 0.00, energy:    1.661
# Molecular Orbital 467, occupation: 0.00, energy:    1.662
# Molecular Orbital 468, occupation: 0.00, energy:    1.672
# Molecular Orbital 469, occupation: 0.00, energy:    1.672
# Molecular Orbital 470, occupation: 0.00, energy:    1.673
# Molecular Orbital 471, occupation: 0.00, energy:    1.673
# Molecular Orbital 472, occupation: 0.00, energy:    1.674
# Molecular Orbital 473, occupation: 0.00, energy:    1.674
# Molecular Orbital 474, occupation: 0.00, energy:    1.674
# Molecular Orbital 475, occupation: 0.00, energy:    1.674
# Molecular Orbital 476, occupation: 0.00, energy:    1.675
# Molecular Orbital 477, occupation: 0.00, energy:    1.690
# Molecular Orbital 478, occupation: 0.00, energy:    1.690
# Molecular Orbital 479, occupation: 0.00, energy:    1.690
# Molecular Orbital 480, occupation: 0.00, energy:    1.691
# Molecular Orbital 481, occupation: 0.00, energy:    1.691
# Molecular Orbital 482, occupation: 0.00, energy:    1.741
# Molecular Orbital 483, occupation: 0.00, energy:    1.742
# Molecular Orbital 484, occupation: 0.00, energy:    1.742
# Molecular Orbital 485, occupation: 0.00, energy:    1.769
# Molecular Orbital 486, occupation: 0.00, energy:    1.770
# Molecular Orbital 487, occupation: 0.00, energy:    1.771
# Molecular Orbital 488, occupation: 0.00, energy:    1.771
# Molecular Orbital 489, occupation: 0.00, energy:    1.782
# Molecular Orbital 490, occupation: 0.00, energy:    1.782
# Molecular Orbital 491, occupation: 0.00, energy:    1.782
# Molecular Orbital 492, occupation: 0.00, energy:    1.794
# Molecular Orbital 493, occupation: 0.00, energy:    1.795
# Molecular Orbital 494, occupation: 0.00, energy:    1.795
# Molecular Orbital 495, occupation: 0.00, energy:    1.915
# Molecular Orbital 496, occupation: 0.00, energy:    1.934
# Molecular Orbital 497, occupation: 0.00, energy:    1.934
# Molecular Orbital 498, occupation: 0.00, energy:    1.934
# Molecular Orbital 499, occupation: 0.00, energy:    1.935
# Molecular Orbital 500, occupation: 0.00, energy:    1.935
# Molecular Orbital 501, occupation: 0.00, energy:    1.937
# Molecular Orbital 502, occupation: 0.00, energy:    1.937
# Molecular Orbital 503, occupation: 0.00, energy:    1.938
# Molecular Orbital 504, occupation: 0.00, energy:    1.938
# Molecular Orbital 505, occupation: 0.00, energy:    2.197
# Molecular Orbital 506, occupation: 0.00, energy:    2.197
# Molecular Orbital 507, occupation: 0.00, energy:    2.198
# Molecular Orbital 508, occupation: 0.00, energy:    2.198
# Molecular Orbital 509, occupation: 0.00, energy:    2.199
# Molecular Orbital 510, occupation: 0.00, energy:    2.228
# Molecular Orbital 511, occupation: 0.00, energy:    2.230
# Molecular Orbital 512, occupation: 0.00, energy:    2.230
# Molecular Orbital 513, occupation: 0.00, energy:    2.237
# Molecular Orbital 514, occupation: 0.00, energy:    2.238
# Molecular Orbital 515, occupation: 0.00, energy:    2.239
# Molecular Orbital 516, occupation: 0.00, energy:    2.475
# Molecular Orbital 517, occupation: 0.00, energy:    2.475
# Molecular Orbital 518, occupation: 0.00, energy:    2.475
# Molecular Orbital 519, occupation: 0.00, energy:    2.476
# Molecular Orbital 520, occupation: 0.00, energy:    2.476
# Molecular Orbital 521, occupation: 0.00, energy:    2.565
# Molecular Orbital 522, occupation: 0.00, energy:    2.565
# Molecular Orbital 523, occupation: 0.00, energy:    2.565
# Molecular Orbital 524, occupation: 0.00, energy:    2.835
# Molecular Orbital 525, occupation: 0.00, energy:    2.838
# Molecular Orbital 526, occupation: 0.00, energy:    2.841
# Molecular Orbital 527, occupation: 0.00, energy:    2.842
# Molecular Orbital 528, occupation: 0.00, energy:    2.908
# Molecular Orbital 529, occupation: 0.00, energy:    2.908
# Molecular Orbital 530, occupation: 0.00, energy:    2.909
# Molecular Orbital 531, occupation: 0.00, energy:    2.910
# Molecular Orbital 532, occupation: 0.00, energy:    2.910
# Molecular Orbital 533, occupation: 0.00, energy:    3.344
# Molecular Orbital 534, occupation: 0.00, energy:    3.346
# Molecular Orbital 535, occupation: 0.00, energy:    3.350
# Molecular Orbital 536, occupation: 0.00, energy:    3.354
# Molecular Orbital 537, occupation: 0.00, energy:    3.587
# Molecular Orbital 538, occupation: 0.00, energy:    3.588
# Molecular Orbital 539, occupation: 0.00, energy:    3.592

# %% [markdown]
# ## H2 binding energy curve

# %%
# Out:
# Total HF energy: 0.4 -0.9506786580943305 Hartree
# Total HF energy: 0.6 -1.1319534605884076 Hartree
# Total HF energy: 0.8 -1.150027881209585 Hartree
# Total HF energy: 0.9 -1.1406024516864692 Hartree
# Total HF energy: 1.0 -1.1267783519580556 Hartree
# Total HF energy: 1.1 -1.1112698792995999 Hartree
# Total HF energy: 1.4 -1.0667752729709794 Hartree
# Total HF energy: 1.8 -1.0261357171893148 Hartree
# Total HF energy: 2.5 -1.0008131478562312 Hartree
# Total HF energy: 3.5 -0.996689871523255 Hartree
# Total HF energy: 4.5 -0.9964731737747944 Hartree
# Total HF energy: 6 -0.9964658254839056 Hartree
# Total HF energy: 10 -0.9964658214581413 Hartree
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-60f4c2d50e6c> in <module>()
#      19                   'e_convergence': 1e-8})
#      20
# ---> 21   E = psi4.energy('fci',return_wfn=False)
#      22   print('Total HF energy: {0} {1} Hartree'.format(i, E))
#      23
#
# ~/psi4conda/lib/python3.6/site-packages/psi4/driver/driver.py in energy(name, **kwargs)
#     458             shutil.copy(item, targetfile)
#     459
# --> 460     wfn = procedures['energy'][lowername](lowername, molecule=molecule, **kwargs)
#     461
#     462     for postcallback in hooks['energy']['post']:
#
# ~/psi4conda/lib/python3.6/site-packages/psi4/driver/procrouting/proc.py in run_detci(name, **kwargs)
#    2951     ref_wfn = kwargs.get('ref_wfn', None)
#    2952     if ref_wfn is None:
# -> 2953         ref_wfn = scf_helper(name, **kwargs)  # C1 certified
#    2954
#    2955     # Ensure IWL files have been written
#
# ~/psi4conda/lib/python3.6/site-packages/psi4/driver/procrouting/proc.py in scf_helper(name, **kwargs)
#    1328         scf_wfn.set_variable("-D Energy", disp_energy)
#    1329
# -> 1330     e_scf = scf_wfn.compute_energy()
#    1331     core.set_variable("SCF TOTAL ENERGY", e_scf)
#    1332     core.set_variable("CURRENT ENERGY", e_scf)
#
# RuntimeError:
# Fatal Error: Iterations did not converge.
# Error occurred in file: /scratch/psilocaluser/conda-builds/psi4_1495014881710/work/psi4/src/psi4/libparallel/process.cc on line: 194
# The most recent 5 function calls were:
#
# psi::PsiException::PsiException(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, char const*, int)
# psi::die_if_not_converged()
# psi::scf::HF::finalize_E()
# psi::scf::HF::compute_energy()
