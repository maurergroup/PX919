# %% [markdown]
# <h2> <center> Tutorial on <br> The Particle in a box  </center> </h2>
#
# <br>
# <h3> <center> Reinhard J. Maurer </center> </h3>

# %% [markdown]
# <div class="col-md-12">
#                     <h2> The particle in a box </h2>
#                     <div class="col-md-12">
#                     <div class="col-md-4">
#                         <div class="col-md-10">
#                             <img src="tik1d.png" alt="Motivation">
#                         </div>
#                     </div>
#                     <div class="col-md-8">
#                         <p>  Schrödinger equation (SE): $\quad\hat{H}\psi = E\psi $</p>
#                         <p class="">
#                         SE: Hamilton ('energy') operator $\hat{H}$ defines the energy and wave function $\psi$  </p>
#                         <p class=""> $$ \hat{H} = -\frac{\hbar^2}{2m}\frac{d^2}{dx^2}  $$</p>
#                         <p class=" margin-top-10"> boundary conditions: $ \psi(0) = 0 \quad\text{and}\quad \psi(L) = 0 $</p>
#                     </div>
#                     </div>
#                     <div class="col-md-6">
#                         <b> wave functions ('eigenfunctions')</b>
#                         <p> $$ \psi_n(x) = \sqrt{\frac{2}{L}}\sin{\frac{n\pi}{L}}  $$  </p>
#                     </div>
#                     <div class="col-md-6">
#                         <b> energies ('eigenvalues') </b>
#                         <p> $$ E_n = \frac{\hbar^2\pi^2}{2m}\frac{n^2}{L^2}  $$  </p>
#                     </div>
# </div>

# %%
from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('livereveal', {
          #'width': 1024,
          #'height': 768,
          'width': 1600,
          'height': 1200,    
})

import numpy as np
import warnings
warnings.filterwarnings('ignore')
from qmp import *
from qmp.basis.gridbasis import *
from qmp.potential.pot_tools import create_potential

from bokeh.layouts import gridplot, widgetbox, column
from bokeh.plotting import figure, output_file, show
from bokeh.models import LinearAxis, Range1d
from bokeh.models import HoverTool
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Slider
from bokeh.models import TapTool, CustomJS
from bokeh.models import Span
from bokeh.models import Label
from bokeh.models.glyphs import HBar

from bokeh.io import output_notebook, push_notebook, show
from bokeh.palettes import viridis, magma

from ipywidgets import interact

output_notebook()

N=50
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
lw = 2.0
colors = magma(N)
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="99f199d1-9cc6-4217-91aa-194533aa75c6">Loading BokehJS ...</span>
#     </div>

# %%
cell = [[-4.0,20.0]]

def do_calcs1(m=1.0,L=5):
    f = create_potential(cell, name='box', box_pos=L/2.0, box_width=L, box_height=1000000.)
    pot = Potential(cell, f=f)    
    x = np.linspace(-4,11,2000)
    E = np.zeros(50)
    psi = np.zeros([len(x),50])
    for i in range(50):
        E[i] = ((i+1)*(i+1)*np.pi*np.pi)/(2*m*L*L)
        psi[:,i] = np.sin(x*(i+1)*np.pi/L)*np.sqrt(2/L)
    for i, xx in enumerate(x):
        if xx<0. or xx>L:
            psi[i,:] = 0.0
    dens = psi*psi
    
    return x, E, pot, psi, dens

      
def do_calcs(m=1.0,L=5):

    f = create_potential(cell, name='box', box_pos=L/2.0, box_width=L, box_height=10.)
    pot = Potential(cell, f=f)

    states = 50
    pib = Model(ndim=1,
           mass=m,
           mode='wave',
           basis='onedgrid',
           solver='scipy',
           states=states,
           )

    pib.set_potential(pot)

    N=1000
    b = onedgrid(cell[0][0], cell[0][1], N)
    pib.set_basis(b)

    pib.solve()

    x = pib.basis.x
    E = pib.data.wvfn.E
    psi = pib.data.wvfn.psi
    #for i in range(states):
    dx = x[1]-x[0]
    psi /= np.sqrt(dx)
    dens = np.abs(psi*np.conjugate(psi))
    
    
    return x, E, pot, psi, dens

def do_calcs2(m=1.0,L=5):
    
    def f(x):
        x = np.array([x]).flatten()
        for i, xx in enumerate(x):
            if xx< 0.0 or xx> L:
                x[i] = 1000000.
            elif xx>=0.0 and xx<=0.4*L:
                x[i] = 0.0
            elif xx>=0.6*L and xx<=L:
                x[i] = 0.0
            else:
                x[i] = 1.0
        return x
        
    pot = Potential(cell, f=f)

    states = 50
    pib = Model(ndim=1,
           mass=m,
           mode='wave',
           basis='onedgrid',
           solver='scipy',
           states=states,
           )

    pib.set_potential(pot)

    N=1000
    b = onedgrid(cell[0][0], cell[0][1], N)
    pib.set_basis(b)

    pib.solve()

    x = pib.basis.x
    E = pib.data.wvfn.E
    psi = pib.data.wvfn.psi
    #for i in range(states):
    dx = x[1]-x[0]
    psi /= np.sqrt(dx)
    dens = np.abs(psi*np.conjugate(psi))
    
    
    return x, E, pot, psi, dens

# %%
L = 5.0
x, E, pot, psi, dens = do_calcs1(L=L)

source1 = ColumnDataSource(data=dict(E=E, right=np.ones(len(E))*L,color=colors))
source2 = ColumnDataSource(data=dict(x=x, y=pot(x)))
source3 = ColumnDataSource(data=dict(x=x, y=-psi[:,0]))
source4 = ColumnDataSource(data=dict(x=x, y=dens[:,0]))

source_vbar = ColumnDataSource(
        data=dict(
            x=[0,L],
        )
    )
#source2 = ColumnDataSource(
##        data=dict(
#            x=x,
#            y=E,
#       #     desc=,
#        )
#    )
#hover = HoverTool(
#        tooltips=[
#            ("index", "$index"),
#            ("(x,y)", "($x, $y)"),
#           #("desc", "@desc"),
#        ]
#    )

callback = CustomJS(code="""""")
tap = TapTool(callback=callback)
#hover = HoverTool(callback=callback)

TOOLS="pan,wheel_zoom,box_zoom,reset"

p1 = figure(x_axis_label='x (atomic units)',y_axis_label='Energy (atomic units)',
            plot_width=1000, plot_height=600, tools=[tap,'pan','box_zoom','wheel_zoom','reset'])
p1.xaxis.axis_label_text_font_size = "16pt"
p1.yaxis.axis_label_text_font_size = "16pt"
p1.xaxis.major_label_text_font_size= "12pt"
p1.yaxis.major_label_text_font_size= "12pt"
#p.extra_y_ranges = {'pot': Range1d(start=-10, end=10000)}
#p.add_layout(LinearAxis(y_range_name='pot'), 'right')
#p.line(x, pib.pot(x), line_width=lw, line_color='grey', y_range_name='pot' )

line_pot = p1.line('x', 'y', source=source2, line_width=lw+1, line_color='grey' )

p1.x_range=Range1d(-3,10)
p1.y_range=Range1d(-0.3,10)

label1 = Label(x=-1, y=E[0], text='n={0:2d}'.format(1),text_color=colors[0],
              text_font_size='14pt')
p1.add_layout(label1)


#p1.xaxis.axis_label = ''
#p1.yaxis.axis_label = ''

energies = p1.hbar(right='right',y='E',height=0.05, left=0, source=source1, color='color')


p2  = figure(x_axis_label='x (atomic units)',y_axis_label='Wave function', plot_width=400, plot_height=200, 
             tools=TOOLS)
p2.xaxis.axis_label_text_font_size = "16pt"
p2.yaxis.axis_label_text_font_size = "16pt"
p2.xaxis.major_label_text_font_size= "12pt"
p2.yaxis.major_label_text_font_size= "12pt"
#vline1=Span(location=0, dimension='height', line_color='grey', line_width=3.0)
#vline2=Span(location=L, dimension='height', line_color='grey', line_width=3.0)
#p2.renderers.extend([vline1,vline2])
line_psi = p2.line('x','y', source=source3, line_width=lw, line_color='blue')

vbars1 = p2.vbar('x',top=100, source=source_vbar, width=0.05, bottom=-100, color='grey')

p2.x_range=Range1d(-3,10)
p2.y_range=Range1d(-0.7,0.7)

p3  = figure(x_axis_label='x (atomic units)',y_axis_label='Probability', plot_width=400, plot_height=200, 
             tools=TOOLS)
p3.xaxis.axis_label_text_font_size = "16pt"
p3.yaxis.axis_label_text_font_size = "16pt"
p3.xaxis.major_label_text_font_size= "12pt"
p3.yaxis.major_label_text_font_size= "12pt"
#vline3=Span(location=0, dimension='height', line_color='grey', line_width=3.0)
#vline4=Span(location=L, dimension='height', line_color='grey', line_width=3.0)
#p3.renderers.extend([vline3,vline4])
line_dens = p3.line('x','y', source=source4, line_width=lw, line_color='blue')
vbars2 = p3.vbar('x',top=100, source=source_vbar, width=0.05, bottom=-100, color='grey')
p3.x_range=Range1d(-3,10)
p3.y_range=Range1d(-0.1,0.5)
p_box1 = gridplot([[p1],[p2,p3]])

def update(n,m,L):
    x, E, pot, psi, dens = do_calcs1(m=m,L=L)
    line_pot.data_source.data['y'] = pot(x)
    energies.data_source.data['E'] = E
    energies.data_source.data['right'] = np.ones(len(x))*L
    #arrow1.line_color=colors[n-1]
    #arrow1.end.line_color=colors[n-1]
    label1.y=E[n-1]
    label1.text='n={0:2d}'.format(n)
    label1.text_color=colors[n-1]
    line_psi.data_source.data['y'] = psi[:,n-1]
    line_psi.glyph.line_color = colors[n-1]
    line_dens.data_source.data['y'] = dens[:,n-1]
    line_dens.glyph.line_color = colors[n-1]
    vbars1.data_source.data['x'] = [0,L]
    vbars2.data_source.data['x'] = [0,L]
    push_notebook(handle=h1)

# %% [markdown]
# # Particle in a box

# %%
h1=show(p_box1, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="318cb437-9852-4381-98a5-b93fb7236b00"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("318cb437-9852-4381-98a5-b93fb7236b00");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("318cb437-9852-4381-98a5-b93fb7236b00");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '318cb437-9852-4381-98a5-b93fb7236b00' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4cafed5e-5f97-42e3-b2b5-6f8d6af48f70":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d6b07011-6ce8-462f-a9c0-414bcda3a92c","type":"PanTool"},{"id":"b4464788-7570-40ce-baa6-c2fcd234e307","type":"WheelZoomTool"},{"id":"e14c0340-df10-4f73-90f8-e47f65918fea","type":"BoxZoomTool"},{"id":"c0d9939c-6986-4cbf-9524-7859e599bf8e","type":"ResetTool"}]},"id":"5b316c30-0bac-419c-8476-0ca2edaa8bac","type":"Toolbar"},{"attributes":{"overlay":{"id":"7ee9430f-bdd3-4bbe-bc53-0cca2b75cd01","type":"BoxAnnotation"}},"id":"e14c0340-df10-4f73-90f8-e47f65918fea","type":"BoxZoomTool"},{"attributes":{},"id":"ba015c2e-0ac0-4684-abc0-18aa1c5e5cb9","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"56830fb3-8576-43c0-ab58-d4ab4b3abc31","type":"ColumnDataSource"},{"attributes":{},"id":"329db134-9361-4181-a495-20dabdf7b9f3","type":"LinearScale"},{"attributes":{"plot":{"id":"f2f94f6a-1aed-4826-8446-55dff12dad66","subtype":"Figure","type":"Plot"},"ticker":{"id":"875d2de2-a109-4aa4-b648-08acfff9b062","type":"BasicTicker"}},"id":"5efa4aa1-836c-411c-b79d-cd36f47a7cab","type":"Grid"},{"attributes":{"axis_label":"x (atomic units)","axis_label_text_font_size":{"value":"16pt"},"formatter":{"id":"db230a60-8ec6-46f6-ac21-c0ff99ce5386","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"f2f94f6a-1aed-4826-8446-55dff12dad66","subtype":"Figure","type":"Plot"},"ticker":{"id":"875d2de2-a109-4aa4-b648-08acfff9b062","type":"BasicTicker"}},"id":"ddfb21a1-e682-4b9f-9e94-26d7835b92f9","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"612c600b-aaab-429b-b74c-ebd4b7f0bc61","type":"Line"},{"attributes":{},"id":"875d2de2-a109-4aa4-b648-08acfff9b062","type":"BasicTicker"},{"attributes":{"axis_label":"Wave function","axis_label_text_font_size":{"value":"16pt"},"formatter":{"id":"578e1529-39a5-46ee-822b-4154f69ff2ca","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"f2f94f6a-1aed-4826-8446-55dff12dad66","subtype":"Figure","type":"Plot"},"ticker":{"id":"fad9c6ef-2a99-48dd-886f-1ad7b3617034","type":"BasicTicker"}},"id":"39c08fa7-a2d5-4ea7-bc29-7cccc8e26f65","type":"LinearAxis"},{"attributes":{},"id":"fad9c6ef-2a99-48dd-886f-1ad7b3617034","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"f2f94f6a-1aed-4826-8446-55dff12dad66","subtype":"Figure","type":"Plot"},"ticker":{"id":"fad9c6ef-2a99-48dd-886f-1ad7b3617034","type":"BasicTicker"}},"id":"24fbc175-1198-4462-8754-fee08bf6bd0b","type":"Grid"},{"attributes":{},"id":"c0d9939c-6986-4cbf-9524-7859e599bf8e","type":"ResetTool"},{"attributes":{},"id":"db230a60-8ec6-46f6-ac21-c0ff99ce5386","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7ee9430f-bdd3-4bbe-bc53-0cca2b75cd01","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"f0257190-94f9-4359-bb91-04a1814af807","type":"LinearAxis"}],"left":[{"id":"cbd1386d-e73c-4323-8903-87c28eb169f4","type":"LinearAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"f0257190-94f9-4359-bb91-04a1814af807","type":"LinearAxis"},{"id":"a121b825-7095-47d2-afbc-21f834599587","type":"Grid"},{"id":"cbd1386d-e73c-4323-8903-87c28eb169f4","type":"LinearAxis"},{"id":"ff49dc8b-b249-4971-8e9a-f5f42521b8b8","type":"Grid"},{"id":"7f12e07b-791a-495f-ae95-f71243dc0010","type":"BoxAnnotation"},{"id":"47c1f570-1804-4cbf-b90d-1e66ff016 ...

# %%
interact(update, n={*range(1,50)}, m=(0.1,1.9), L=(0.1,19.0))
# Out:
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 2000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 2000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <function __main__.update>

# %% [markdown]
# # Particle in a box with bump in the middle

# %%
L = 5.0
x, E, pot, psi, dens = do_calcs2(L=L)

source1 = ColumnDataSource(data=dict(x=x, E=E, right=np.ones(len(x))*L, color=colors))
source2 = ColumnDataSource(data=dict(x=x, y=pot(x)))
source3 = ColumnDataSource(data=dict(x=x, y=-psi[:,0]))
source4 = ColumnDataSource(data=dict(x=x, y=dens[:,0]))

#source1 = ColumnDataSource(
#        data=dict(
#            x=x,
#            y=pot,
#       #     desc=,
#        )
#    )
#source2 = ColumnDataSource(
##        data=dict(
#            x=x,
#            y=E,
#       #     desc=,
#        )
#    )
#hover = HoverTool(
#        tooltips=[
#            ("index", "$index"),
#            ("(x,y)", "($x, $y)"),
#           #("desc", "@desc"),
#        ]
#    )

callback = CustomJS(code="")
tap = TapTool(callback=callback)
#hover = HoverTool(callback=callback)

TOOLS="pan,wheel_zoom,box_zoom,reset"

p11 = figure(x_axis_label='x (atomic units)',y_axis_label='Energy (atomic units)',
            plot_width=800, plot_height=400, tools=[tap,'pan','box_zoom','wheel_zoom','reset'])
p11.xaxis.axis_label_text_font_size = "16pt"
p11.yaxis.axis_label_text_font_size = "16pt"
p11.xaxis.major_label_text_font_size= "12pt"
p11.yaxis.major_label_text_font_size= "12pt"
#p.extra_y_ranges = {'pot': Range1d(start=-10, end=10000)}
#p.add_layout(LinearAxis(y_range_name='pot'), 'right')
#p.line(x, pib.pot(x), line_width=lw, line_color='grey', y_range_name='pot' )

line_pot1 = p11.line('x', 'y', source=source2, line_width=lw+1, line_color='grey' )

p11.x_range=Range1d(-3,10)
p11.y_range=Range1d(-0.3,12)
#p1.xaxis.axis_label = ''
#p1.yaxis.axis_label = ''

label11 = Label(x=-1, y=E[0], text='n={0:2d}'.format(1),text_color=colors[0],
              text_font_size='14pt')
p11.add_layout(label11)

energies1 = p11.hbar('E', right='right', source=source1, height=0.05, left=0, color='color')

p22  = figure(x_axis_label='x (atomic units)',y_axis_label='Wave function', plot_width=400, plot_height=200, 
              tools=TOOLS)
p22.xaxis.axis_label_text_font_size = "16pt"
p22.yaxis.axis_label_text_font_size = "16pt"
p22.xaxis.major_label_text_font_size= "12pt"
p22.yaxis.major_label_text_font_size= "12pt"
line_psi1 = p22.line('x','y', source=source3, line_width=lw, line_color='blue')
vbars11 = p22.vbar('x',top=100, source=source_vbar, width=0.05, bottom=-100, color='grey')

p22.x_range=Range1d(-3,10)
p22.y_range=Range1d(-0.7,0.7)

p33  = figure(x_axis_label='x (atomic units)',y_axis_label='Density', plot_width=400, plot_height=200, tools=TOOLS)
p33.xaxis.axis_label_text_font_size = "16pt"
p33.yaxis.axis_label_text_font_size = "16pt"
p33.xaxis.major_label_text_font_size= "12pt"
p33.yaxis.major_label_text_font_size= "12pt"
line_dens1 = p33.line('x','y', source=source4, line_width=lw, line_color='blue')
vbars22 = p33.vbar('x',top=100, source=source_vbar, width=0.05, bottom=-100, color='grey')

p_box3 = gridplot([[p11],[p22,p33]])

p33.x_range=Range1d(-3,10)
p33.y_range=Range1d(-0.1,0.5)

def update2(n,m,L):
    x, E, pot, psi, dens = do_calcs2(m=m,L=L)
    line_pot1.data_source.data['y'] = pot(x)
    energies1.data_source.data['E'] = E
    energies1.data_source.data['right'] = np.ones(len(x))*L
    label11.y=E[n-1]
    label11.text='n={0:2d}'.format(n)
    label11.text_color=colors[n-1]
    line_psi1.data_source.data['y'] = psi[:,n-1]
    line_psi1.glyph.line_color = colors[n-1]
    line_dens1.data_source.data['y'] = dens[:,n-1]
    line_dens1.glyph.line_color = colors[n-1]
    vbars11.data_source.data['x'] = [0,L]
    vbars22.data_source.data['x'] = [0,L]
    push_notebook(handle=h3)
# Out:
# Initializing Solver
# Solving...
# SOLVED
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 1000), ('x', 1000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))

# %%
h3=show(p_box3, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0cbe862e-fe7d-4fc7-b2da-8b5c7ba1859b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0cbe862e-fe7d-4fc7-b2da-8b5c7ba1859b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0cbe862e-fe7d-4fc7-b2da-8b5c7ba1859b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0cbe862e-fe7d-4fc7-b2da-8b5c7ba1859b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f9f4d836-9640-4c22-815c-7d07dbb9c746":{"roots":{"references":[{"attributes":{"source":{"id":"4fb7d9c9-435e-4734-999e-2980f28f43d6","type":"ColumnDataSource"}},"id":"ad820328-690e-4402-8077-e5d6dcda2872","type":"CDSView"},{"attributes":{},"id":"805d1a4b-eab0-425f-94d3-123c6e4c696c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"32820d59-de59-446f-981d-602df2f21cb3","subtype":"Figure","type":"Plot"},"text":"n= 1","text_color":{"value":"#546096"},"text_font_size":{"value":"14pt"},"x":-1,"y":0.5001460531588292},"id":"4f42e9bd-8d5d-4a37-8cc9-1364715cb7aa","type":"Label"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"b717b929-baa5-442b-880e-a351b40a8f20","type":"Line"},{"attributes":{},"id":"2bbae43d-c819-49b0-969a-33496c4d33ef","type":"PanTool"},{"attributes":{"fill_color":{"field":"color"},"height":{"value":0.05},"line_color":{"field":"color"},"right":{"field":"right"},"y":{"field":"E"}},"id":"5c7d5cf9-6401-462b-94e5-80aefb91b4d2","type":"HBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.05},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"E"}},"id":"46d74794-4682-4c49-b934-f60555b3fb1f","type":"HBar"},{"attributes":{"source":{"id":"72a737b4-82fe-4f29-be58-5496a55e7ae8","type":"ColumnDataSource"}},"id":"6d076e43-a71e-4ed6-939e-7029c94094d0","type":"CDSView"},{"attributes":{},"id":"82126abb-b0b3-4946-8f25-04954c611674","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2bbae43d-c819-49b0-969a-33496c4d33ef","type":"PanTool"},{"id":"00f50421-c460-4af4-a1cb-a445e6e0653a","type":"WheelZoomTool"},{"id":"997669f5-0a84-4040-8630-5f52c2a0c242","type":"BoxZoomTool"},{"id":"8f0291a3-e19c-412d-af6a-e909d181e5e8","type":"ResetTool"}]},"id":"aab3fc64-7965-445f-a1de-fe15645832ff","type":"Toolbar"},{"attributes":{},"id":"95f5a8c8-b42d-40fc-8a74-2241ec85d417","type":"LinearScale"},{"attributes":{},"id":"00f50421-c460-4af4-a1cb-a445e6e0653a","type":"WheelZoomTool"},{"attributes":{"axis_label":"x (atomic units)","axis_label_text_font_size":{"value":"16pt"},"formatter":{"id":"805d1a4b-eab0-425f-94d3-123c6e4c696c","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"22fd330b-899e-429b-892d-ca3717a89fda","subtype":"Figure","type":"Plot"},"ticker":{"id":"56c0886b-ca52-40f3-87fc-c461a25677d3","type":"BasicTicker"}},"id":"e8f60a0a-5a67-4b8f-947d-c8ec867a1caf","type":"LinearAxis"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c031513-1c7e-4eb2-b79d-ec19427c285a","type":"Line"},{"attributes":{"overlay":{"id":"c7e1001e-3fef-459c-899d-780186985298","type":"BoxAnnotation"}},"id":"997669f5-0a84-4040-8630-5f52c2a0c242","type":"BoxZoomTool"},{"attributes":{},"id":"8f0291a3-e19c-412d-af6a-e909d181e5e8","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c7e1001e-3fef-459c-899d-780186985298","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"72a737b4-82fe-4f29-be58-5496a55e7ae8","type":"ColumnDataSource"},"glyph":{"id":"4c031513-1c7e-4eb2-b79d-ec19427c285a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b717b929-baa5-442b-880e-a351b40a8f20","type":"Line"},"selection_glyph":null,"view":{"id":"6d076e43-a71e-4ed6-939e-7029c94094d0","type":"CDSView"}},"id":"eed3bd0f-ca1a-494a-8ca9-54c518e90311","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"4ddc106a-d30c-4f00-b3fb-114596821934","type":"LinearAxis"}]," ...

# %%
interact(update2, n={*range(1,50)}, m=(0.1,1.9), L=(1.,9.))
# Out:
# Initializing Solver
# Solving...
# SOLVED
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 1000), ('x', 1000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 1000), ('x', 1000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <function __main__.update2>

# %% [markdown]
# # Particle in a box with finite walls

# %%
L = 5.0
x, E, pot, psi, dens = do_calcs(L=L)

source1 = ColumnDataSource(data=dict(x=x, E=E, right=np.ones(len(x))*L, color=colors))
source2 = ColumnDataSource(data=dict(x=x, y=pot(x)))
source3 = ColumnDataSource(data=dict(x=x, y=-psi[:,0]))
source4 = ColumnDataSource(data=dict(x=x, y=dens[:,0]))

#source1 = ColumnDataSource(
#        data=dict(
#            x=x,
#            y=pot,
#       #     desc=,
#        )
#    )
#source2 = ColumnDataSource(
##        data=dict(
#            x=x,
#            y=E,
#       #     desc=,
#        )
#    )
#hover = HoverTool(
#        tooltips=[
#            ("index", "$index"),
#            ("(x,y)", "($x, $y)"),
#           #("desc", "@desc"),
#        ]
#    )

callback = CustomJS(code="")
tap = TapTool(callback=callback)
#hover = HoverTool(callback=callback)

TOOLS="pan,wheel_zoom,box_zoom,reset"

p11 = figure(x_axis_label='x (atomic units)',y_axis_label='Energy (atomic units)',
            plot_width=800, plot_height=400, tools=[tap,'pan','box_zoom','wheel_zoom','reset'])
p11.xaxis.axis_label_text_font_size = "16pt"
p11.yaxis.axis_label_text_font_size = "16pt"
p11.xaxis.major_label_text_font_size= "12pt"
p11.yaxis.major_label_text_font_size= "12pt"
#p.extra_y_ranges = {'pot': Range1d(start=-10, end=10000)}
#p.add_layout(LinearAxis(y_range_name='pot'), 'right')
#p.line(x, pib.pot(x), line_width=lw, line_color='grey', y_range_name='pot' )

line_pot1 = p11.line('x', 'y', source=source2, line_width=lw+1, line_color='grey' )

p11.x_range=Range1d(-3,10)
p11.y_range=Range1d(-0.3,12)
#p1.xaxis.axis_label = ''
#p1.yaxis.axis_label = ''

label11 = Label(x=-1, y=E[0], text='n={0:2d}'.format(1),text_color=colors[0],
              text_font_size='14pt')
p11.add_layout(label11)

energies1 = p11.hbar('E', right='right', source=source1, height=0.05, left=0, color='color')

p22  = figure(x_axis_label='x (atomic units)',y_axis_label='Wave function', plot_width=400, plot_height=200, 
              tools=TOOLS)
p22.xaxis.axis_label_text_font_size = "16pt"
p22.yaxis.axis_label_text_font_size = "16pt"
p22.xaxis.major_label_text_font_size= "12pt"
p22.yaxis.major_label_text_font_size= "12pt"
line_psi1 = p22.line('x','y', source=source3, line_width=lw, line_color='blue')
vbars11 = p22.vbar('x',top=100, source=source_vbar, width=0.05, bottom=-100, color='grey')

p22.x_range=Range1d(-3,10)
p22.y_range=Range1d(-0.7,0.7)

p33  = figure(x_axis_label='x (atomic units)',y_axis_label='Density', plot_width=400, plot_height=200, tools=TOOLS)
p33.xaxis.axis_label_text_font_size = "16pt"
p33.yaxis.axis_label_text_font_size = "16pt"
p33.xaxis.major_label_text_font_size= "12pt"
p33.yaxis.major_label_text_font_size= "12pt"
line_dens1 = p33.line('x','y', source=source4, line_width=lw, line_color='blue')
vbars22 = p33.vbar('x',top=100, source=source_vbar, width=0.05, bottom=-100, color='grey')

p_box2 = gridplot([[p11],[p22,p33]])

p33.x_range=Range1d(-3,10)
p33.y_range=Range1d(-0.1,0.5)

def update1(n,m,L):
    x, E, pot, psi, dens = do_calcs(m=m,L=L)
    line_pot1.data_source.data['y'] = pot(x)
    energies1.data_source.data['E'] = E
    energies1.data_source.data['right'] = np.ones(len(x))*L
    label11.y=E[n-1]
    label11.text='n={0:2d}'.format(n)
    label11.text_color=colors[n-1]
    line_psi1.data_source.data['y'] = psi[:,n-1]
    line_psi1.glyph.line_color = colors[n-1]
    line_dens1.data_source.data['y'] = dens[:,n-1]
    line_dens1.glyph.line_color = colors[n-1]
    vbars11.data_source.data['x'] = [0,L]
    vbars22.data_source.data['x'] = [0,L]
    push_notebook(handle=h2)
# Out:
# Initializing Solver
# Solving...
# SOLVED
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 1000), ('x', 1000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))

# %%
h2=show(p_box2, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6a7d742a-39f0-48fa-95df-9c3aa47b142b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6a7d742a-39f0-48fa-95df-9c3aa47b142b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6a7d742a-39f0-48fa-95df-9c3aa47b142b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6a7d742a-39f0-48fa-95df-9c3aa47b142b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cbb95520-b459-4b52-a0d7-af6b0bbddc1d":{"roots":{"references":[{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac1f38ec-a0e4-47ac-bccc-a76e0380388d","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"41e1e266-4af9-4ddb-b1ca-d36226e2db44","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"4423a0bf-bc74-43f6-94cc-7b052d7f2c30","type":"ColumnDataSource"},{"attributes":{},"id":"a9a8e2e1-efa5-4872-9f59-79eb95a565d6","type":"CustomJS"},{"attributes":{},"id":"a1601441-7112-446a-8a2e-e591652e9baa","type":"WheelZoomTool"},{"attributes":{"bottom":{"value":-100},"fill_color":{"value":"grey"},"line_color":{"value":"grey"},"top":{"value":100},"width":{"value":0.05},"x":{"field":"x"}},"id":"8106bd22-e74b-479e-bb5b-486c2c2dbf66","type":"VBar"},{"attributes":{"callback":{"id":"a9a8e2e1-efa5-4872-9f59-79eb95a565d6","type":"CustomJS"}},"id":"4b2f9208-933f-453e-ad27-a65be48968c3","type":"TapTool"},{"attributes":{"below":[{"id":"968a411d-fbb2-4cc6-bb69-61398bbbe661","type":"LinearAxis"}],"left":[{"id":"41bec2fe-18e3-4496-850a-3ce37b801254","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"968a411d-fbb2-4cc6-bb69-61398bbbe661","type":"LinearAxis"},{"id":"de882db9-396e-4004-bcf7-e868c7bbbaab","type":"Grid"},{"id":"41bec2fe-18e3-4496-850a-3ce37b801254","type":"LinearAxis"},{"id":"ee8b46be-d0e4-4454-9921-d01e055b9771","type":"Grid"},{"id":"b5118b17-9962-487d-a42e-0f9a22e940c9","type":"BoxAnnotation"},{"id":"5643499a-1d3b-4052-b848-5bff25562b7e","type":"GlyphRenderer"},{"id":"a0aa9d3f-c7ac-4edd-9474-e998e729cf50","type":"Label"},{"id":"79021422-58e9-4292-899d-1c86c9cad95b","type":"GlyphRenderer"}],"title":{"id":"6b0b8c6b-8d4a-4c5e-ad7d-7402b9028246","type":"Title"},"toolbar":{"id":"4ef1698f-dc15-45c0-a616-212919660299","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"f759c854-4864-4668-948f-eb8f0c23a95c","type":"Range1d"},"x_scale":{"id":"cd75bc4a-fe7f-4a1d-afe3-404efc67852b","type":"LinearScale"},"y_range":{"id":"b6b89528-0bc8-4a2b-9b96-a028a47c8862","type":"Range1d"},"y_scale":{"id":"9d678d9f-16dc-430c-8dac-5bed15229c85","type":"LinearScale"}},"id":"19b7ce2d-6f1d-4388-bb12-8f58368a2cab","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4b2f9208-933f-453e-ad27-a65be48968c3","type":"TapTool"},{"id":"80f13637-357b-401f-89d1-5be5caf82ac4","type":"PanTool"},{"id":"487d83ea-e1dd-4bd4-a9bb-7de2b606c365","type":"BoxZoomTool"},{"id":"8fc01ec9-c744-4f63-8534-9d58e14b2cd8","type":"WheelZoomTool"},{"id":"e6d23a9c-3a1f-45c9-ba23-c3b88720fc45","type":"ResetTool"}]},"id":"4ef1698f-dc15-45c0-a616-212919660299","type":"Toolbar"},{"attributes":{},"id":"9e22f78f-2021-438f-94dd-96a5fd6403b1","type":"PanTool"},{"attributes":{"callback":null,"end":10,"start":-3},"id":"f759c854-4864-4668-948f-eb8f0c23a95c","type":"Range1d"},{"attributes":{},"id":"9d678d9f-16dc-430c-8dac-5bed15229c85","type":"LinearScale"},{"attributes":{},"id":"cd75bc4a-fe7f-4a1d-afe3-404efc67852b","type":"LinearScale"},{"attributes":{"plot":{"id":"19b7ce2d-6f1d-4388-bb12-8f58368a2cab","subtype":"Figure","type":"Plot"},"ticker":{"id":"51552339-9ef6-4545-8232-813f3f66da65","type":"BasicTicker"}},"id":"de882db9-396e-4004-bcf7-e868c7bbbaab","type":"Grid"},{"attributes":{"axis_label":"x (atomic units)","axis_label_text_font_size":{"value":"16pt"},"formatter":{"id":"c1f3c216-0878-44df-98b5-c328da6b79fb","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"19b7ce2d-6f1d-4388-bb12-8f58368a2cab","subtype":"Figure","type":"Plot"},"ti ...

# %%
interact(update1, n={*range(1,50)}, m=(0.1,1.9), L=(1.,9.))
# Out:
# Initializing Solver
# Solving...
# SOLVED
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 1000), ('x', 1000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /home/reini/psi4conda/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('E', 50), ('color', 50), ('right', 1000), ('x', 1000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <function __main__.update1>

# %% [markdown]
# <div class="col-md-12">
#      <h3> Problem 1 </h3>
#     <p  style="color:blue;"> <u>a</u>: Let's assume that the electron is in state n=2. What is the required energy to bring it into state n=3? </p>
#     <div class="fragment">
#     <p> $\Delta E=E(n=3)-E(n=2)= \frac{\hbar^2\pi^2}{2mL^2}(9-4)=5\cdot E_1 $
#     </p>
#     </div>
#     <p  style="color:blue;"> <u>b</u>: Calculate the energy difference E(n=3)-E(n=2) for a box (molecule) of size L/2?</p>
#      <div class="fragment">
#     <p> $$ \Delta E=5\cdot \frac{\hbar^2\pi^2}{2m(L/2)^2}=5\cdot4\cdot \frac{\hbar^2\pi^2}{2mL^2} = 20\cdot E_1 $$ </p>
#     <p> Smaller CdSe nanoparticles emit light with higher energy (blue) </p>
#     </div>
# </div>

# %% [markdown]
# <div class="col-md-12">
#      <h3> Problem 2 </h3>
#     <p  style="color:blue;"> <u>a</u>: What happens to the energy spectrum and the wave functions when the box width L becomes very large? What happens to the energy of the n=1 state? </p>
#     <div class="fragment">
#     <p> All energy spacings become very close to zero. The $E_1$ energy also approaches zero.
#     $L\rightarrow\infty$  approaches the limit of a free particle, where states are not quantized and there is no zero-point energy. </p> <br>
#     <b> !Quantized energy levels with spacings are a consequence of confinement!
#     </b>
# </div>

# %% [markdown]
# <div class="col-md-12">
#      <h3> Problem 3 </h3>
#
#     <p   style="color:blue;"> <u>a</u>: In a realistic system, the potential wall will not be infinitely high and electrons will be able to escape eventually. What will be the consequence for the wave functions inside the well?  </p>
#     <div class="fragment">
#     <p> The wave functions do not strictly have to be 0 at the boundaries any more, but rather exponentially decay to zero. This means that the electrons can 'tunnel' into the barrier region.
#     </p>
#     </div>
#     <p   style="color:blue;"> <u>b</u>:In a finite well, only a finite number of states has energies that lie below the well edge. What do wave functions describe that lie above this well edge? </p>
#     <div class="fragment">
#     <p> These wave functions will describe electrons with higher probability to be found outside the well, so-called 'unbound states' with properties similar to free electrons.
#     </p>
#     </div>
# </div>
